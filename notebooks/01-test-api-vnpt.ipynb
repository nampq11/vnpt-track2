# %%
import os
import requests
import json

# %%
vnpt_auth = [
  {
    "authorization": "Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....JPROLaIH2HbYXxRxOD4WfSbka9_MMG7nYtFaSITBKTCMkE6InLqER9tv8K2CZt_ZTeo7yeiICyl5MDBlzsQVMMmj21MGTNsRU9PztTEfRcjJ72FUX8gbTO7bQufiN8XtFBcrxwbipshiyFflzT1Vzrr6iU48jHUZwIwPMpx8r_a8ftFkt-fpX2IdVvJJ6I3ncfqHy_qfYp_IZnlCZN1JtLqpEYkv1l8SDSoQNF-Z2tzB0ODgL_mDcmwjp1k2dzeELiMvU7nd8Vk7yNWXWf30HUDzUAQC1u-4irKGKn2OS01-PWXJSrILCgcMe-hegLnY6gus9Gv381k4UaSoqyNq9A",
    "tokenKey": "MFwwDQYJKoZIhvcNAQEBBQADSwAwSAJBAIJOyfQMRnX/ic9PRldIS9sgersAAdrisjiy6uF9qkA4BHkcyB9GdaZ9JeO2NgqJnAljWH05dwTOwvVQPHHAIFkCAwEAAQ==",
    "llmApiName": "LLM embedings",
    "tokenId": "456eda22-1324-1660-e063-63199f0a4a52"
  },
  {
    "authorization": "Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....JPROLaIH2HbYXxRxOD4WfSbka9_MMG7nYtFaSITBKTCMkE6InLqER9tv8K2CZt_ZTeo7yeiICyl5MDBlzsQVMMmj21MGTNsRU9PztTEfRcjJ72FUX8gbTO7bQufiN8XtFBcrxwbipshiyFflzT1Vzrr6iU48jHUZwIwPMpx8r_a8ftFkt-fpX2IdVvJJ6I3ncfqHy_qfYp_IZnlCZN1JtLqpEYkv1l8SDSoQNF-Z2tzB0ODgL_mDcmwjp1k2dzeELiMvU7nd8Vk7yNWXWf30HUDzUAQC1u-4irKGKn2OS01-PWXJSrILCgcMe-hegLnY6gus9Gv381k4UaSoqyNq9A",
    "tokenKey": "MFwwDQYJKoZIhvcNAQEBBQADSwAwSAJBAIQNpVG7Awn8hsNfiaQkmXmThjga6ToacizDk9UtH2lGYRzaO+zm+VQP1IEm+7btZtO7RPU82ezP3hMCHy66QksCAwEAAQ==",
    "llmApiName": "LLM small",
    "tokenId": "456eddc6-06f4-2a30-e063-63199f0a8d59"
  },
  {
    "authorization": "Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....JPROLaIH2HbYXxRxOD4WfSbka9_MMG7nYtFaSITBKTCMkE6InLqER9tv8K2CZt_ZTeo7yeiICyl5MDBlzsQVMMmj21MGTNsRU9PztTEfRcjJ72FUX8gbTO7bQufiN8XtFBcrxwbipshiyFflzT1Vzrr6iU48jHUZwIwPMpx8r_a8ftFkt-fpX2IdVvJJ6I3ncfqHy_qfYp_IZnlCZN1JtLqpEYkv1l8SDSoQNF-Z2tzB0ODgL_mDcmwjp1k2dzeELiMvU7nd8Vk7yNWXWf30HUDzUAQC1u-4irKGKn2OS01-PWXJSrILCgcMe-hegLnY6gus9Gv381k4UaSoqyNq9A",
    "tokenKey": "MFwwDQYJKoZIhvcNAQEBBQADSwAwSAJBAJV0uOkT5+QiTGlZ3C7l3w9uQ+/1EKnIQ4//PdYxhYqt/0L3Vi6T/Dw3M3T4Ut9Ac5V6woBz2wxzdTkcJ4VRjWECAwEAAQ==",
    "llmApiName": "LLM large",
    "tokenId": "456edce6-d2d9-2228-e063-63199f0ae873"
  }
]

# %%
vnpt_auth[1]
# Out:
# {'authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....JPROLaIH2HbYXxRxOD4WfSbka9_MMG7nYtFaSITBKTCMkE6InLqER9tv8K2CZt_ZTeo7yeiICyl5MDBlzsQVMMmj21MGTNsRU9PztTEfRcjJ72FUX8gbTO7bQufiN8XtFBcrxwbipshiyFflzT1Vzrr6iU48jHUZwIwPMpx8r_a8ftFkt-fpX2IdVvJJ6I3ncfqHy_qfYp_IZnlCZN1JtLqpEYkv1l8SDSoQNF-Z2tzB0ODgL_mDcmwjp1k2dzeELiMvU7nd8Vk7yNWXWf30HUDzUAQC1u-4irKGKn2OS01-PWXJSrILCgcMe-hegLnY6gus9Gv381k4UaSoqyNq9A',
#  'tokenKey': 'MFwwDQYJKoZIhvcNAQEBBQADSwAwSAJBAIQNpVG7Awn8hsNfiaQkmXmThjga6ToacizDk9UtH2lGYRzaO+zm+VQP1IEm+7btZtO7RPU82ezP3hMCHy66QksCAwEAAQ==',
#  'llmApiName': 'LLM small',
#  'tokenId': '456eddc6-06f4-2a30-e063-63199f0a8d59'}

# %%
import requests
headers = {
    'Authorization': vnpt_auth[1]['authorization'],
    'Token-id': vnpt_auth[1]['tokenId'],
    'Token-key': vnpt_auth[1]['tokenKey'],
    'Content-Type': 'application/json',
}
json_data = {
    'model': 'vnptai_hackathon_small',
    'messages': [
    {
    'role': 'user',
    'content': 'Hi, VNPT AI.',
    },
    ],
    'temperature': 1.0,
    'top_p': 1.0,
    'top_k': 20,
    'n': 1,
    'max_completion_tokens': 10,
}

# %%
headers
# Out:
# {'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....JPROLaIH2HbYXxRxOD4WfSbka9_MMG7nYtFaSITBKTCMkE6InLqER9tv8K2CZt_ZTeo7yeiICyl5MDBlzsQVMMmj21MGTNsRU9PztTEfRcjJ72FUX8gbTO7bQufiN8XtFBcrxwbipshiyFflzT1Vzrr6iU48jHUZwIwPMpx8r_a8ftFkt-fpX2IdVvJJ6I3ncfqHy_qfYp_IZnlCZN1JtLqpEYkv1l8SDSoQNF-Z2tzB0ODgL_mDcmwjp1k2dzeELiMvU7nd8Vk7yNWXWf30HUDzUAQC1u-4irKGKn2OS01-PWXJSrILCgcMe-hegLnY6gus9Gv381k4UaSoqyNq9A',
#  'Token-id': '456eddc6-06f4-2a30-e063-63199f0a8d59',
#  'Token-key': 'MFwwDQYJKoZIhvcNAQEBBQADSwAwSAJBAIQNpVG7Awn8hsNfiaQkmXmThjga6ToacizDk9UtH2lGYRzaO+zm+VQP1IEm+7btZtO7RPU82ezP3hMCHy66QksCAwEAAQ==',
#  'Content-Type': 'application/json'}

# %%
response = requests.post('https://api.idg.vnpt.vn/data-service/v1/chat/completions/vnptai-hackathon-small', headers=headers, json=json_data)
response.json()
# Out:
# {'path': '/v1/chat/completions/vnptai-hackathon-small',
#  'dataSign': 'gHcvD7fBHCoEYTlaN4JpVCJm5imD23Vs2HseVAjySqcviriK8iJO1ML5cuo1OwBHySKdVd+1RkVM2YDGbM6fMQ==',
#  'dataBase64': '',
#  'logID': 'e1b341a1-dc24-11f0-8eea-71fdc0d3c551-2fb9cec0-Zuulserver',
#  'error': 'Internal Server Error',
#  'message': 'syscall:getsockopt(..) failed: Connection refused: /10.165.24.196:30041',
#  'timestamp': '2025-12-18T15:19:01.213+0000',
#  'status': 500,
#  'challengeCode': '11111'}
